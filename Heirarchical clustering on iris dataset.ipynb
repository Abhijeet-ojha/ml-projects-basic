# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()

X = iris.data
y = iris.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=y, palette='Set1')
# Out:
# <Axes: >

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

linked = linkage(X_scaled, method='ward')
plt.figure(figsize=(10, 7))
dendrogram(linked)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample index')
plt.ylabel('Distance')
# Out:
# Text(0, 0.5, 'Distance')

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3)
y_pred = cluster.fit_predict(X_scaled)

# %%
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], c=y_pred, palette='Set1')
# Out:
# C:\Users\Abhijeet ojha\AppData\Local\Temp\ipykernel_21232\2033198835.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], c=y_pred, palette='Set1')
# <Axes: >
